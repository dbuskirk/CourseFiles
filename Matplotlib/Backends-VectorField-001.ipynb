# %% [markdown]
# Available matplotlib backends: <br />
# 'osx', 'qt4', 'qt5', 'gtk3', 'notebook', 'wx', 'qt', 'nbagg','gtk', 'tk', 'inline'

# %% [markdown]
# An alternate backend must be specified before the import of matplotlib. Otherwise the "inline" magic will be automatically applied.<br/>
# Once you have selected a backend, you cannot switch to another without restarting the kernel.

# %%
# %matplotlib --list

# %%
# %matplotlib svg 
# fig.savefig() will save files in svg format

# %%
# On WIntel Python WM, the backend is loaded without error, but will hang if you try to use it!!
# re-confirmed 20210615
# %matplotlib tk 
# works on server Ulam
# works on server Hypatia

# %%
# %matplotlib gtk %error on Wintel Python VM
# %matplotlib gtk3 #error on Wintel Python VM: "No module named 'Cairo'"
# %matplotlib qt 
# works on Wintel Python VM
# works on Ulam
# works on Hypatia

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.arange(-10, 10, 1)
Y = np.arange(-10, 10, 1)
U, V = np.meshgrid(X, Y)

fig, ax = plt.subplots()
q = ax.quiver(X, Y, U, V)
ax.quiverkey(q, X=0.3, Y=1.1, U=10,
             label='Quiver key, length = 10', labelpos='E')

plt.show()
# fig.savefig("test.svg")

# %%
dir(fig)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_axes_internal',
#  '_agg_filter',
#  '_align_label_groups',
#  '_alpha',
#  '_animated',
#  '_axobservers',
#  '_axstack',
#  '_button_pick_id',
#  '_cachedRenderer',
#  '_callbacks',
#  '_canvas_callbacks',
#  '_clipon',
#  '_clippath',
#  '_constrained',
#  '_constrained_layout_pads',
#  '_contains',
#  '_default_contains',
#  '_dpi',
#  '_gci',
#  '_get_clipping_extent_bbox',
#  '_get_dpi',
#  '_get_draw_artists',
#  '_gid',
#  '_gridspecs',
#  '_in_layout',
#  '_label',
#  '_layoutgrid',
#  '_localaxes',
#  '_mouseover',
# ...

# %%
# %matplotlib ipympl # interactive matplotlib

# %%
# %matplotlib widget # interactive matpotlib
