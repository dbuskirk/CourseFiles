# %% [markdown]
# ## Dan's Notes: Creating Matplotlib Subplots
#
# ©2019-2021 Daniel R. Buskirk<br/>
# danbuskirk1729@gmail.com<br/>

# %% [markdown]
# ## Table of Contents
# 1. [Introduction](#introduction)
# 2. [Imports](#imports)
#  * [Version Dependencies](#versiondependencies)
#  <p></p>
# 3. [Creating Subplots](#creatingsubplots)
# 6. [References](#references)
# 7. [Appendix: Data and Execution Notes](#dataandexecutionnotes)

# %% [markdown]
# <a name="introduction"></a>
# ### Introduction

# %% [markdown]
# Different authors and blogger uses a variety of different coding styles when creating Matplotb subplots. Since they are generally focusing on some other aspect of plot creation, these differences are often not explains. In this notebooks we collect a variety of different subplot creation styles for learning and for comparison.

# %% [markdown]
# <a name="imports"></a>
# ### Imports

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

# %% [markdown]
# Some imports of general utility

# %%
import sys

# %% [markdown]
# #### Versions

# %%
print('Python v{}'.format(str(sys.version[0]) + "." + str(sys.version[2])+ "." + str(sys.version[4])))
print('Matplotlib v{}'.format(mpl.__version__))
# Out:
# Python v3.7.4
# Matplotlib v3.4.2

# %% [markdown]
# <a name="versiondependencies"></a>
# #### Version Dependencies
# There are no special version specificities for this notebook.

# %% [markdown]
# #### External File Dependencies<br />

# %% [markdown]
# <a name="creatingsubplots"></a><br />
# ## Creating Subplots

# %%
fig, ax = plt.subplots(1)
plt.show()

# %% [markdown]
# We can set values to optional properties when we create the subplots.

# %%
fig, ax = plt.subplots(1, figsize=(8,8))
plt.show()

# %% [markdown]
# Or, we can use the references we have called fig and ax to set properties later.

# %%
fig, ax = plt.subplots(1 )
fig.figsize=(4,4)
plt.show()

# %% [markdown]
# As is always the case, there are many ways to accomplish the task of creating and using subplots. Subplots can be created at once and then referenced individually, or subplots can be added one-by-one to an existing plot.<br>

# %% [markdown]
# ### Creating Subplots All-at-Once

# %%
fig, ax = plt.subplots(4,4)

plt.show()

# %% [markdown]
# Looks pretty ugly, so we will try it again using <b>constrained_layout=True</b>.

# %%
fig, ax = plt.subplots(4,4, constrained_layout=True)

# %% [markdown]
# Actually, constrained_layout=True might be a good candidate for setting as a default for this document.

# %%
# mpl.rcParams.keys()

# %%
mpl.rcParams['figure.constrained_layout.use'] = True

# %% [markdown]
# ### fig and ax

# %% [markdown]
# "fig" and "ax" are far-and-away the most commonly chosen variable names to refer to figure objects and axis arrays. However, there are several different coding styles to choose from. One option is to let ax remain an array and use matrix notation when we want to access a particular axis.

# %%
fig, ax = plt.subplots(4,4)
ax[1,2].set_facecolor('red')
plt.show()

# %% [markdown]
# An alternative syntax is to capture individual axis references when we create them.

# %%
fig, [[ax1, ax2],[ax3, ax4]] = plt.subplots(2,2)
ax3.set_facecolor('green')
plt.show()

# %% [markdown]
# ### Creating Subplots One-At-A-Time

# %% [markdown]
# Some folks prefer to use the RCI notation, in which the 221 just looks like an integer, but really means we are creating an array with 2 rows, 2 columns, and the subplot we are creating is instance 1 (of a possible 4).

# %%
ax1=plt.subplot(221)
ax2=plt.subplot(223, projection='polar')

# %% [markdown]
# This is exactly equivalent to

# %%
ax1=plt.subplot(2,2,1)
ax2=plt.subplot(2,2,3, projection='polar')

# %% [markdown]
# See what happens when we change the instance number of the polar plot.

# %%
ax1=plt.subplot(221)
ax2=plt.subplot(222, projection='polar')

# %% [markdown]
# ### Creating Subplots One-At-A-Time

# %% [markdown]
# #### Using figure.add_subplot( )

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

# %%
fig = plt.figure()
fig.add_subplot(1, 2, 1)   #top and bottom left
#plt.plot(names, values)
fig.add_subplot(2, 2, 2)   #top right
plt.plot(names, values)
fig.add_subplot(2, 2, 4)   #bottom right 
#plt.plot(names, values)
plt.show()

# %% [markdown]
# <a name="references"></a><br />
# ### References

# %% [markdown]
# <a name="dataandexecutionnotes"></a>
# ### Data and Execution Notes

# %% [markdown]
# Notebook tested on Wintel Python virtual machine 20210627.
